# %%
# for general data wrangling tasks
import pandas as pd

# to read and visualize spatial data
import geopandas as gpd
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
# to provide basemaps 
import contextily as ctx

# to give more power to your figures (plots)
import matplotlib.pyplot as plt

# %%
g2011 = gpd.read_file('data2011/data2.csv')

# %%
g2011.head()
# Out:
#        B03002_001E             B03002_001M  \
# 0  Estimate!!Total  Margin of Error!!Total
# 1             2451                     194
# 2             2103                     142
# 3             5088                     370
# 4             3943                     427
#
#                                B03002_002E  \
# 0  Estimate!!Total!!Not Hispanic or Latino
# 1                                     2366
# 2                                     1914
# 3                                     4627
# 4                                     3493
#
#                                       B03002_002M  \
# 0  Margin of Error!!Total!!Not Hispanic or Latino
# 1                                             196
# 2                                             169
# 3                                             350
# 4                                             435
#
#                                          B03002_003E  \
# 0  Estimate!!Total!!Not Hispanic or Latino!!White...
# ...

# %%
g2011 = g2011.drop([0])

# %%
g2011.head()
# Out:
#   B03002_001E B03002_001M B03002_002E B03002_002M B03002_003E B03002_003M  \
# 1        2451         194        2366         196        1894         235
# 2        2103         142        1914         169        1470         214
# 3        5088         370        4627         350        3542         319
# 4        3943         427        3493         435        2624         420
# 5        3481         319        3120         342        1668         204
#
#   B03002_004E B03002_004M B03002_005E B03002_005M  ... B03002_019E  \
# 1         124          88           0          95  ...          17
# 2          72          49          13          21  ...          95
# 3         584         133          39          49  ...          23
# 4         339          84          29          45  ...           8
# 5        1066         285          11          18  ...          54
#
#   B03002_019M B03002_020E B03002_020M B03002_021E B03002_021M  \
# ...

# %%
list(g2011)
# Out:
# ['B03002_001E',
#  'B03002_001M',
#  'B03002_002E',
#  'B03002_002M',
#  'B03002_003E',
#  'B03002_003M',
#  'B03002_004E',
#  'B03002_004M',
#  'B03002_005E',
#  'B03002_005M',
#  'B03002_006E',
#  'B03002_006M',
#  'B03002_007E',
#  'B03002_007M',
#  'B03002_008E',
#  'B03002_008M',
#  'B03002_009E',
#  'B03002_009M',
#  'B03002_010E',
#  'B03002_010M',
#  'B03002_011E',
#  'B03002_011M',
#  'B03002_012E',
#  'B03002_012M',
#  'B03002_013E',
#  'B03002_013M',
#  'B03002_014E',
#  'B03002_014M',
#  'B03002_015E',
#  'B03002_015M',
#  'B03002_016E',
#  'B03002_016M',
#  'B03002_017E',
#  'B03002_017M',
#  'B03002_018E',
#  'B03002_018M',
#  'B03002_019E',
#  'B03002_019M',
#  'B03002_020E',
#  'B03002_020M',
#  'B03002_021E',
#  'B03002_021M',
#  'GEO_ID',
#  'GEOID',
#  'NAME',
#  'geometry']

# %%
czip = "zip:///tl_2021_06_tract.zip/tl_2021_06_tract.shp"

# %%
counties = gpd.read_file('data/tl_2021_06_tract.shp')

# %%
counties.head()
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID     NAME              NAMELSAD  MTFCC  \
# 0      06      085  504321  06085504321  5043.21  Census Tract 5043.21  G5020
# 1      06      085  504410  06085504410  5044.10  Census Tract 5044.10  G5020
# 2      06      085  507003  06085507003  5070.03  Census Tract 5070.03  G5020
# 3      06      085  507004  06085507004  5070.04  Census Tract 5070.04  G5020
# 4      06      085  502204  06085502204  5022.04  Census Tract 5022.04  G5020
#
#   FUNCSTAT    ALAND  AWATER     INTPTLAT      INTPTLON  \
# 0        S  1450237       0  +37.3931319  -121.8651427
# 1        S  1102136       0  +37.4093719  -121.8788884
# 2        S  9529865       0  +37.2199936  -121.9979512
# 3        S  2424447       0  +37.2260144  -121.9763816
# 4        S   331145       0  +37.3013832  -121.9258424
#
#                                             geometry
# 0  POLYGON ((-121.87556 37.39924, -121.87535 37.3...
# 1  POLYGON ((-121.88886 37.40758, -121.88576 37.4...
# ...

# %%
type(g2011['GEOID'])
# Out:
# pandas.core.series.Series

# %%
geo2011 = g2011.merge(counties, on='GEOID')

# %%
geo2011.head()
# Out:
#   B03002_001E B03002_001M B03002_002E B03002_002M B03002_003E B03002_003M  \
# 0        2451         194        2366         196        1894         235
# 1        2103         142        1914         169        1470         214
# 2        5088         370        4627         350        3542         319
# 3        3943         427        3493         435        2624         420
# 4        3481         319        3120         342        1668         204
#
#   B03002_004E B03002_004M B03002_005E B03002_005M  ... TRACTCE NAME_y  \
# 0         124          88           0          95  ...  400100   4001
# 1          72          49          13          21  ...  400200   4002
# 2         584         133          39          49  ...  400300   4003
# 3         339          84          29          45  ...  400400   4004
# 4        1066         285          11          18  ...  400500   4005
#
#             NAMELSAD  MTFCC FUNCSTAT    ALAND AWATER     INTPTLAT  \
# ...

# %%
c2011meta = gpd.read_file('data2011/ACSDT5Y2011.B03002_metadata_2022-01-23T164149.csv')

# %%
header = list(geo2011)

# %%
header

# %%
c2011meta.head()

# %%
c2011meta.shape

# %%
c2011meta

# %%
header2
